# %% [markdown]
# # CA05 – kNN based Movie Recommender Engine

# %%
#Importing the necessary packages:
import pandas as pd
import numpy as np
from sklearn import neighbors
from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors

# %%
#Importing the dataset
movie_df = pd.read_csv('https://github.com/ArinB/MSBA-CA-Data/raw/main/CA05/movies_recommendation_data.csv')
movie_df
# Out:
#     Movie ID                        Movie Name  IMDB Rating  Biography  Drama  \
# 0         58                The Imitation Game          8.0          1      1
# 1          8                        Ex Machina          7.7          0      1
# 2         46                  A Beautiful Mind          8.2          1      1
# 3         62                 Good Will Hunting          8.3          0      1
# 4         97                      Forrest Gump          8.8          0      1
# 5         98                                21          6.8          0      1
# 6         31                            Gifted          7.6          0      1
# 7          3               Travelling Salesman          5.9          0      1
# 8         51                            Avatar          7.9          0      0
# 9         47                    The Karate Kid          7.2          0      1
# 10        50            A Brilliant Young Mind          7.2          0      1
# ...

# %% [markdown]
# # Data Cleaning and Analysis

# %%
#Checking the column names
movie_df.columns
# Out:
# Index(['Movie ID', 'Movie Name', 'IMDB Rating', 'Biography', 'Drama',
#        'Thriller', 'Comedy', 'Crime', 'Mystery', 'History', 'Label'],
#       dtype='object')

# %%
#Checking the size of the dataset, by checking the number of rows and columns in the dataset
movie_df.shape
# Out:
# (30, 11)

# %%
#Checking the data type of each column
movie_df.dtypes
# Out:
# Movie ID         int64
# Movie Name      object
# IMDB Rating    float64
# Biography        int64
# Drama            int64
# Thriller         int64
# Comedy           int64
# Crime            int64
# Mystery          int64
# History          int64
# Label            int64
# dtype: object

# %%
#Checking to see if there are any missing values in each column
movie_df.isnull().sum()
# Out:
# Movie ID       0
# Movie Name     0
# IMDB Rating    0
# Biography      0
# Drama          0
# Thriller       0
# Comedy         0
# Crime          0
# Mystery        0
# History        0
# Label          0
# dtype: int64

# %%
#Droping the irrelevant Label column
movie_df = movie_df.drop('Label', axis=1)

# %% [markdown]
# # Building the Movie Recommender System

# %% [markdown]
# Goal: Given a movies data set, what are the 5 most similar movies to a movie query?

# %%
#Defining the variables
x = df[['IMDB Rating', 'Biography', 'Drama', 'Thriller', 'Comedy', 'Crime', 'Mystery', 'History']]
y = df['Movie Name']

# %%
#Applying NearestNeighbors functions to variables
df_NN = NearestNeighbors(n_neighbors=5) 
df_NN.fit(x,y)
# Out:
# NearestNeighbors()

# %%
#Creating a list that contains "The Post"'s attributes
The_Post = [7.2, 1, 1, 0, 0, 0, 0, 1]

# %%
#Finding the k nearest neighbors of The Post 
The_Post = pd.DataFrame([The_Post], columns=x.columns)
distance, movie_row = df_NN.kneighbors(The_Post)

# %% [markdown]
# # Movie Recommendations

# %%
#Finding movies according to their row
nearest_movie_names = df.iloc[movie_row[0]]['Movie Name'].values

#Displaying the titles for recommendations
print(" Top 5 Recommended Movies for Lovers of: The Post \n")
for title in nearest_movie_names:
    print(title)
# Out:
#  Top 5 Recommended Movies for Lovers of: The Post
#
# 12 Years a Slave
# Hacksaw Ridge
# Queen of Katwe
# The Wind Rises
# A Beautiful Mind
